# %% [markdown]
# # **1. pymongo 설치**
# pymongo는 파이썬에서 MongoDB와 상호작용하기 위해 사용하는 공식 Python 클라이언트 라이브러리입니다. 이 라이브러리를 사용하면 MongoDB에 데이터를 쉽게 삽입, 조회, 수정, 삭제할 수 있습니다.

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.13.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.13.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 3.3 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 20.6 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.13.2

# %% [markdown]
# # **2. 몽고DB 서버와의 연결**

# %%
from pymongo import MongoClient

# %%
url = 'mongodb+srv://apple:<비밀번호>@cluster0.vydmxz2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
client = MongoClient(url)
print(client)
# Out:
# MongoClient(host=['ac-ep5z1yx-shard-00-00.vydmxz2.mongodb.net:27017', 'ac-ep5z1yx-shard-00-02.vydmxz2.mongodb.net:27017', 'ac-ep5z1yx-shard-00-01.vydmxz2.mongodb.net:27017'], document_class=dict, tz_aware=False, connect=True, retrywrites=True, w='majority', appname='Cluster0', authsource='admin', replicaset='atlas-8bxs33-shard-0', tls=True)

# %%
database = client['aiproject']
collection = database['user']

# %% [markdown]
# # **3.데이터 추가**

# %%
user_insert = {'user':'apple', 'name':'김사과','age': 20}
result = collection.insert_one(user_insert)
result.inserted_id
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /tmp/ipython-input-5-365564681.py in <cell line: 0>()
#       1 user_insert = {'user':'apple', 'name':'김사과','age': 20}
# ----> 2 result = collection.insert_one(user_insert)
#       3 result.inserted_id
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/collection.py in insert_one(self, document, bypass_document_validation, session, comment)
#     889         write_concern = self._write_concern_for(session)
#     890         return InsertOneResult(
# --> 891             self._insert_one(
#     892                 document,
#     893                 ordered=True,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/collection.py in _insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     829             _check_write_command_response(result)
#     830
# --> 831         self._database.client._retryable_write(
#     832             acknowledged, _insert_command, session, operation=_Op.INSERT
#     833         )
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2059         """
#    2060         with self._tmp_session(session) as s:
# -> 2061             return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#    2062
#    2063     def _cleanup_cursor_no_lock(
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1945             retryable and self.options.retry_writes and session and not session.in_transaction
#    1946         )
# -> 1947         return self._retry_internal(
#    1948             func=func,
#    1949             session=session,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1991             retryable=retryable,
#    1992             operation_id=operation_id,
# -> 1993         ).run()
#    1994
#    1995     def _retryable_read(
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2728             self._check_last_error(check_csot=True)
#    2729             try:
# -> 2730                 return self._read() if self._is_read else self._write()
#    2731             except ServerSelectionTimeoutError:
#    2732                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _write(self)
#    2839             is_mongos = False
#    2840             self._server = self._get_server()
# -> 2841             with self._client._checkout(self._server, self._session) as conn:
#    2842                 max_wire_version = conn.max_wire_version
#    2843                 sessions_supported = (
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _checkout(self, server, session)
#    1754                 yield session._pinned_connection
#    1755                 return
# -> 1756             with server.checkout(handler=err_handler) as conn:
#    1757                 # Pin this session to the selected server or connection.
#    1758                 if (
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in checkout(self, handler)
#    1117             )
#    1118
# -> 1119         conn = self._get_conn(checkout_started_time, handler=handler)
#    1120
#    1121         duration = time.monotonic() - checkout_started_time
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in _get_conn(self, checkout_started_time, handler)
#    1279                 else:  # We need to create a new connection
#    1280                     try:
# -> 1281                         conn = self.connect(handler=handler)
#    1282                     finally:
#    1283                         with self._max_connecting_cond:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in connect(self, handler)
#    1071                 handler.contribute_socket(conn, completed_handshake=False)
#    1072
# -> 1073             conn.authenticate()
#    1074         # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1075         except BaseException:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in authenticate(self, reauthenticate)
#     524                 from pymongo.synchronous import auth
#     525
# --> 526                 auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     527             self.ready = True
#     528             duration = time.monotonic() - self.creation_time
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in authenticate(credentials, conn, reauthenticate)
#     448         _authenticate_oidc(credentials, conn, reauthenticate)
#     449     else:
# --> 450         auth_func(credentials, conn)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in _authenticate_default(credentials, conn)
#     353             return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354         else:
# --> 355             return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356     else:
#     357         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in _authenticate_scram(credentials, conn, mechanism)
#     133         "payload": Binary(client_final),
#     134     }
# --> 135     res = conn.command(source, cmd)
#     136
#     137     parsed = _parse_scram_response(res["payload"])
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/helpers.py in inner(*args, **kwargs)
#      45
#      46         try:
# ---> 47             return func(*args, **kwargs)
#      48         except OperationFailure as exc:
#      49             if no_reauth:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     412             self._raise_if_not_writable(unacknowledged)
#     413         try:
# --> 414             return command(
#     415                 self,
#     416                 dbname,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210                 client._process_response(response_doc, session)
#     211             if check:
# --> 212                 helpers_shared._check_command_response(
#     213                     response_doc,
#     214                     conn.max_wire_version,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/helpers_shared.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     248         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     249
# --> 250     raise OperationFailure(errmsg, code, response, max_wire_version)
#     251
#     252
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
users_insert = [
    {'userid':'banana', 'name':'반하나', 'age': 25},
    {'userid':'orange', 'name':'오렌지', 'age': 30},
    {'userid':'melon', 'name':'이메론', 'age': 28}
]

result = collection.insert_many(users_insert)
result.inserted_ids
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /tmp/ipython-input-6-3462605520.py in <cell line: 0>()
#       5 ]
#       6
# ----> 7 result = collection.insert_many(users_insert)
#       8 result.inserted_ids
#
# /usr/local/lib/python3.11/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     973         blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     974         blk.ops = list(gen())
# --> 975         blk.execute(write_concern, session, _Op.INSERT)
#     976         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     977
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/bulk.py in execute(self, write_concern, session, operation)
#     749                 return None
#     750         else:
# --> 751             return self.execute_command(generator, write_concern, session, operation)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/bulk.py in execute_command(self, generator, write_concern, session, operation)
#     602
#     603         client = self.collection.database.client
# --> 604         _ = client._retryable_write(
#     605             self.is_retryable,
#     606             retryable_bulk,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2059         """
#    2060         with self._tmp_session(session) as s:
# -> 2061             return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#    2062
#    2063     def _cleanup_cursor_no_lock(
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1945             retryable and self.options.retry_writes and session and not session.in_transaction
#    1946         )
# -> 1947         return self._retry_internal(
#    1948             func=func,
#    1949             session=session,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1991             retryable=retryable,
#    1992             operation_id=operation_id,
# -> 1993         ).run()
#    1994
#    1995     def _retryable_read(
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2728             self._check_last_error(check_csot=True)
#    2729             try:
# -> 2730                 return self._read() if self._is_read else self._write()
#    2731             except ServerSelectionTimeoutError:
#    2732                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _write(self)
#    2839             is_mongos = False
#    2840             self._server = self._get_server()
# -> 2841             with self._client._checkout(self._server, self._session) as conn:
#    2842                 max_wire_version = conn.max_wire_version
#    2843                 sessions_supported = (
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _checkout(self, server, session)
#    1754                 yield session._pinned_connection
#    1755                 return
# -> 1756             with server.checkout(handler=err_handler) as conn:
#    1757                 # Pin this session to the selected server or connection.
#    1758                 if (
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in checkout(self, handler)
#    1117             )
#    1118
# -> 1119         conn = self._get_conn(checkout_started_time, handler=handler)
#    1120
#    1121         duration = time.monotonic() - checkout_started_time
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in _get_conn(self, checkout_started_time, handler)
#    1279                 else:  # We need to create a new connection
#    1280                     try:
# -> 1281                         conn = self.connect(handler=handler)
#    1282                     finally:
#    1283                         with self._max_connecting_cond:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in connect(self, handler)
#    1071                 handler.contribute_socket(conn, completed_handshake=False)
#    1072
# -> 1073             conn.authenticate()
#    1074         # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1075         except BaseException:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in authenticate(self, reauthenticate)
#     524                 from pymongo.synchronous import auth
#     525
# --> 526                 auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     527             self.ready = True
#     528             duration = time.monotonic() - self.creation_time
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in authenticate(credentials, conn, reauthenticate)
#     448         _authenticate_oidc(credentials, conn, reauthenticate)
#     449     else:
# --> 450         auth_func(credentials, conn)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in _authenticate_default(credentials, conn)
#     353             return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354         else:
# --> 355             return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356     else:
#     357         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in _authenticate_scram(credentials, conn, mechanism)
#     133         "payload": Binary(client_final),
#     134     }
# --> 135     res = conn.command(source, cmd)
#     136
#     137     parsed = _parse_scram_response(res["payload"])
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/helpers.py in inner(*args, **kwargs)
#      45
#      46         try:
# ---> 47             return func(*args, **kwargs)
#      48         except OperationFailure as exc:
#      49             if no_reauth:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     412             self._raise_if_not_writable(unacknowledged)
#     413         try:
# --> 414             return command(
#     415                 self,
#     416                 dbname,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210                 client._process_response(response_doc, session)
#     211             if check:
# --> 212                 helpers_shared._check_command_response(
#     213                     response_doc,
#     214                     conn.max_wire_version,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/helpers_shared.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     248         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     249
# --> 250     raise OperationFailure(errmsg, code, response, max_wire_version)
#     251
#     252
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %% [markdown]
# # **4. 데이터 조회하기**

# %%
user_find = {'userid':'apple'}
result = collection.find_one(user_find)
result
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# /tmp/ipython-input-7-3945424980.py in <cell line: 0>()
#       1 user_find = {'userid':'apple'}
# ----> 2 result = collection.find_one(user_find)
#       3 result
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/collection.py in find_one(self, filter, *args, **kwargs)
#    1753             filter = {"_id": filter}
#    1754         cursor = self.find(filter, *args, **kwargs)
# -> 1755         for result in cursor.limit(-1):
#    1756             return result
#    1757         return None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/cursor.py in __next__(self)
#    1282
#    1283     def __next__(self) -> _DocumentType:
# -> 1284         return self.next()
#    1285
#    1286     def __iter__(self) -> Cursor[_DocumentType]:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/cursor.py in next(self)
#    1258         if self._empty:
#    1259             raise StopIteration
# -> 1260         if len(self._data) or self._refresh():
#    1261             return self._data.popleft()
#    1262         else:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/cursor.py in _refresh(self)
#    1206                 self._exhaust,
#    1207             )
# -> 1208             self._send_message(q)
#    1209         elif self._id:  # Get More
#    1210             if self._limit:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/cursor.py in _send_message(self, operation)
#    1100
#    1101         try:
# -> 1102             response = client._run_operation(
#    1103                 operation, self._unpack_response, address=self._address
#    1104             )
#
# /usr/local/lib/python3.11/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _run_operation(self, operation, unpack_res, address)
#    1915             )
#    1916
# -> 1917         return self._retryable_read(
#    1918             _cmd,
#    1919             operation.read_preference,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retryable_read(self, func, read_pref, session, operation, address, retryable, operation_id)
#    2024             retryable and self.options.retry_reads and not (session and session.in_transaction)
#    2025         )
# -> 2026         return self._retry_internal(
#    2027             func,
#    2028             session,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/_csot.py in csot_wrapper(self, *args, **kwargs)
#     123                     with _TimeoutContext(timeout):
#     124                         return func(self, *args, **kwargs)
# --> 125             return func(self, *args, **kwargs)
#     126
#     127     return cast(F, csot_wrapper)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1991             retryable=retryable,
#    1992             operation_id=operation_id,
# -> 1993         ).run()
#    1994
#    1995     def _retryable_read(
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in run(self)
#    2728             self._check_last_error(check_csot=True)
#    2729             try:
# -> 2730                 return self._read() if self._is_read else self._write()
#    2731             except ServerSelectionTimeoutError:
#    2732                 # The application may think the write was never attempted
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _read(self)
#    2875         self._server = self._get_server()
#    2876         assert self._read_pref is not None, "Read Preference required on read calls"
# -> 2877         with self._client._conn_from_server(self._read_pref, self._server, self._session) as (
#    2878             conn,
#    2879             read_pref,
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _conn_from_server(self, read_preference, server, session)
#    1844         # to call _get_topology() again.
#    1845         single = self._topology.description.topology_type == TOPOLOGY_TYPE.Single
# -> 1846         with self._checkout(server, session) as conn:
#    1847             if single:
#    1848                 if conn.is_repl and not (session and session.in_transaction):
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/mongo_client.py in _checkout(self, server, session)
#    1754                 yield session._pinned_connection
#    1755                 return
# -> 1756             with server.checkout(handler=err_handler) as conn:
#    1757                 # Pin this session to the selected server or connection.
#    1758                 if (
#
# /usr/lib/python3.11/contextlib.py in __enter__(self)
#     135         del self.args, self.kwds, self.func
#     136         try:
# --> 137             return next(self.gen)
#     138         except StopIteration:
#     139             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in checkout(self, handler)
#    1117             )
#    1118
# -> 1119         conn = self._get_conn(checkout_started_time, handler=handler)
#    1120
#    1121         duration = time.monotonic() - checkout_started_time
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in _get_conn(self, checkout_started_time, handler)
#    1279                 else:  # We need to create a new connection
#    1280                     try:
# -> 1281                         conn = self.connect(handler=handler)
#    1282                     finally:
#    1283                         with self._max_connecting_cond:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in connect(self, handler)
#    1071                 handler.contribute_socket(conn, completed_handshake=False)
#    1072
# -> 1073             conn.authenticate()
#    1074         # Catch KeyboardInterrupt, CancelledError, etc. and cleanup.
#    1075         except BaseException:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in authenticate(self, reauthenticate)
#     524                 from pymongo.synchronous import auth
#     525
# --> 526                 auth.authenticate(creds, self, reauthenticate=reauthenticate)
#     527             self.ready = True
#     528             duration = time.monotonic() - self.creation_time
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in authenticate(credentials, conn, reauthenticate)
#     448         _authenticate_oidc(credentials, conn, reauthenticate)
#     449     else:
# --> 450         auth_func(credentials, conn)
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in _authenticate_default(credentials, conn)
#     353             return _authenticate_scram(credentials, conn, "SCRAM-SHA-256")
#     354         else:
# --> 355             return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#     356     else:
#     357         return _authenticate_scram(credentials, conn, "SCRAM-SHA-1")
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/auth.py in _authenticate_scram(credentials, conn, mechanism)
#     133         "payload": Binary(client_final),
#     134     }
# --> 135     res = conn.command(source, cmd)
#     136
#     137     parsed = _parse_scram_response(res["payload"])
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/helpers.py in inner(*args, **kwargs)
#      45
#      46         try:
# ---> 47             return func(*args, **kwargs)
#      48         except OperationFailure as exc:
#      49             if no_reauth:
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/pool.py in command(self, dbname, spec, read_preference, codec_options, check, allowable_errors, read_concern, write_concern, parse_write_concern_error, collation, session, client, retryable_write, publish_events, user_fields, exhaust_allowed)
#     412             self._raise_if_not_writable(unacknowledged)
#     413         try:
# --> 414             return command(
#     415                 self,
#     416                 dbname,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/synchronous/network.py in command(conn, dbname, spec, is_mongos, read_preference, codec_options, session, client, check, allowable_errors, address, listeners, max_bson_size, read_concern, parse_write_concern_error, collation, compression_ctx, use_op_msg, unacknowledged, user_fields, exhaust_allowed, write_concern)
#     210                 client._process_response(response_doc, session)
#     211             if check:
# --> 212                 helpers_shared._check_command_response(
#     213                     response_doc,
#     214                     conn.max_wire_version,
#
# /usr/local/lib/python3.11/dist-packages/pymongo/helpers_shared.py in _check_command_response(response, max_wire_version, allowable_errors, parse_write_concern_error)
#     248         raise CursorNotFound(errmsg, code, response, max_wire_version)
#     249
# --> 250     raise OperationFailure(errmsg, code, response, max_wire_version)
#     251
#     252
#
# OperationFailure: bad auth : authentication failed, full error: {'ok': 0, 'errmsg': 'bad auth : authentication failed', 'code': 8000, 'codeName': 'AtlasError'}

# %%
result = collection.find({})
for data in result:
    print(data)

# %% [markdown]
# # **5. 데이터 수정**

# %%
user_update = {'userid':'apple'}
new_value = {'$set':{'age':30}}
result = collection.update_one(user_update, new_value)
result

# %% [markdown]
# # **6. 데이터 삭제**

# %%
user_delete = {'userid':'apple'}
result = collection.delete_one(user_delete)
result

# %% [markdown]
# # **7. 종합예제**

# %%
db = client['food_review_db']
foods = db['foods']
users = db['users']
ratings = db['ratings']

# %%
from pymongo import MongoClient
from bson import ObjectId

url = 'mongodb+srv://apple:aTT8BIRMq8Xz44j0@cluster0.vydmxz2.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0'
client = MongoClient(url)

db = client["food_review_db"]

foods = db["foods"]
users = db["users"]
ratings = db["ratings"]

# 사용자 등록
def register_user():
    username = input("🍽️ 닉네임을 입력하세요: ")
    result = users.insert_one({"username": username})
    print(f"👋 환영합니다, {username}님!")
    return result.inserted_id

# 음식 목록 보여주기
def show_foods():
    print("\n📦 현재 등록된 음식:")
    for food in foods.find():
        print(f"- ({food['_id']}) {food['name']} | 종류: {food['category']} | 지역: {food['region']}")

# 음식 추가
def add_food():
    name = input("🍜 음식 이름: ")
    category = input("🍱 음식 종류 (예: 중식, 한식, 분식 등): ")
    region = input("📍 배달 가능 지역: ")
    foods.insert_one({"name": name, "category": category, "region": region})
    print("✅ 음식이 등록되었습니다.")

# 음식 삭제
def delete_food():
    show_foods()
    food_id = input("🗑️ 삭제할 음식의 ID를 입력하세요: ")
    foods.delete_one({"_id": ObjectId(food_id)})
    ratings.delete_many({"food_id": ObjectId(food_id)})
    print("🗑️ 음식과 관련된 모든 리뷰가 삭제되었습니다.")

# 음식에 평점 주기
def rate_food(user_id):
    show_foods()
    food_id = input("⭐ 평점 줄 음식의 ID 입력: ")
    score = float(input("🌟 평점 (0~10): "))
    comment = input("✍️ 한 줄 리뷰: ")
    ratings.insert_one({
        "user_id": user_id,
        "food_id": ObjectId(food_id),
        "score": score,
        "comment": comment
    })
    print("🎉 평점이 등록되었습니다.")

# 평점 수정
def update_rating(user_id):
    print("\n📝 내 리뷰 목록:")
    for r in ratings.find({"user_id": user_id}):
        food = foods.find_one({"_id": r["food_id"]})
        print(f" - ({r['_id']}) {food['name']}: {r['score']}점 | {r['comment']}")

    rating_id = input("수정할 리뷰 ID 입력: ")
    new_score = float(input("새 평점: "))
    new_comment = input("새 리뷰: ")
    ratings.update_one(
        {"_id": ObjectId(rating_id)},
        {"$set": {"score": new_score, "comment": new_comment}}
    )
    print("✅ 리뷰가 수정되었습니다.")

# 특정 음식 리뷰 보기
def show_food_reviews():
    show_foods()
    food_id = input("🔍 리뷰를 보고 싶은 음식 ID 입력: ")
    print("\n💬 해당 음식의 리뷰 목록:")
    for r in ratings.find({"food_id": ObjectId(food_id)}):
        user = users.find_one({"_id": r["user_id"]})
        print(f"- {user['username']} 님: {r['score']}점 | \"{r['comment']}\"")

# 평점 높은 음식 Top 3
def show_best_foods():
    print("\n🏆 별점이 높은 음식 Top 3:")
    pipeline = [
        {"$group": {"_id": "$food_id", "avg": {"$avg": "$score"}}},
        {"$sort": {"avg": -1}},
        {"$limit": 3}
    ]
    results = ratings.aggregate(pipeline)
    for r in results:
        food = foods.find_one({"_id": r["_id"]})
        print(f"- {food['name']} | 평균 별점: {round(r['avg'], 2)}점")

# 메인 메뉴
def main():
    print("🍔✨ 음식 평점 앱에 오신 걸 환영합니다! ✨🍜\n")
    user_id = register_user()

    while True:
        print("\n📋 메뉴:")
        print("1. 음식 목록 보기")
        print("2. 음식 등록하기")
        print("3. 음식 삭제하기")
        print("4. 음식 별점 남기기")
        print("5. 내 리뷰 수정하기")
        print("6. 음식 리뷰 보기")
        print("7. 별점 높은 음식 TOP 3 보기")
        print("0. 종료하기")

        choice = input("👉 메뉴 선택: ")
        if choice == "1":
            show_foods()
        elif choice == "2":
            add_food()
        elif choice == "3":
            delete_food()
        elif choice == "4":
            rate_food(user_id)
        elif choice == "5":
            update_rating(user_id)
        elif choice == "6":
            show_food_reviews()
        elif choice == "7":
            show_best_foods()
        elif choice == "0":
            print("👋 안녕히 가세요! 맛있는 하루 되세요!")
            break
        else:
            print("❗ 유효한 선택지를 입력해주세요.")

if __name__ == "__main__":
    main()
# Out:
# 🍔✨ 음식 평점 앱에 오신 걸 환영합니다! ✨🍜
#
# 🍽️ 닉네임을 입력하세요: 바하나
# 👋 환영합니다, 바하나님!
#
# 📋 메뉴:
# 1. 음식 목록 보기
# 2. 음식 등록하기
# 3. 음식 삭제하기
# 4. 음식 별점 남기기
# 5. 내 리뷰 수정하기
# 6. 음식 리뷰 보기
# 7. 별점 높은 음식 TOP 3 보기
# 0. 종료하기
# 👉 메뉴 선택: 1
#
# 📦 현재 등록된 음식:
# - (687706cdad9a4558cb99fbda) 짬뽕 | 종류: 중식 | 지역: 역삼동
#
# 📋 메뉴:
# 1. 음식 목록 보기
# 2. 음식 등록하기
# 3. 음식 삭제하기
# 4. 음식 별점 남기기
# 5. 내 리뷰 수정하기
# 6. 음식 리뷰 보기
# 7. 별점 높은 음식 TOP 3 보기
# 0. 종료하기
# 👉 메뉴 선택: 2
# 🍜 음식 이름: 3
# 🍱 음식 종류 (예: 중식, 한식, 분식 등): 한식
# 📍 배달 가능 지역: 역삼
# ✅ 음식이 등록되었습니다.
#
# 📋 메뉴:
# 1. 음식 목록 보기
# 2. 음식 등록하기
# 3. 음식 삭제하기
# 4. 음식 별점 남기기
# 5. 내 리뷰 수정하기
# 6. 음식 리뷰 보기
# 7. 별점 높은 음식 TOP 3 보기
# 0. 종료하기
# 👉 메뉴 선택: 0
# 👋 안녕히 가세요! 맛있는 하루 되세요!
